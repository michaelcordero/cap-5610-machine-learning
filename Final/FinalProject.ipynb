# %% [markdown]
# **<h2>Image classifier with Keras</h2>**

# %% [markdown]
# **<h3>1. Import modules</h3>**
# * *Image* is used later to load the images.
# * *Sequential* allows you to add layers to the model in sequential order.
# * *Dense*, *Conv2D*, *MaxPooling2D*, *Dropout*, and *Flatten* are layers used to add to the model later.
# * *Adam* is an optimizer that uses learning rates for each parameter during training.
# * *LabelEncoder* is used to encode categorical labels as integer values.

# %%
import os
import csv
import numpy as np
from PIL import Image
from PIL.Image import Resampling
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
# Out:
# 2023-03-03 15:57:04.465595: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# **<h3>2. Get paths for datasets and images</h3>**

# %%
# Set the directories for the image dataset and the training dataset
print(os.getcwd())
# os.chdir('/Users/michaelcordero/PycharmProjects/cap-5610-machine-learning/Final')
# print(os.getcwd())
image_dir = 'input/fiu-cap5610-spring-2023/images'
train_data_file = 'input/fiu-cap5610-spring-2023/train.csv'
test_data_file = 'input/fiu-cap5610-spring-2023/test.csv'
# Out:
# /
# /Users/michaelcordero/PycharmProjects/cap-5610-machine-learning/Final

# %% [markdown]
# **<h3>3. Set image dimensions and number of possible labels</h3>**

# %%
# Set the image dimensions and number of classes
img_rows, img_cols = 112, 224
num_classes = 20

# %% [markdown]
# **<h3>4. Load datasets and extract data</h3>**

# %%
# Load the training data
train_data = np.genfromtxt(train_data_file, delimiter=',', dtype=None, encoding=None, skip_header=1)
# Extract the image ids and labels from the training data
train_ids = [str(train_data[i][0]) for i in range(len(train_data))]
train_labels = [str(train_data[i][1]) for i in range(len(train_data))]

# Load the test data
test_data = np.genfromtxt(test_data_file, delimiter=',', dtype=None, encoding=None, skip_header=1)
# Extract the image ids from the test data
test_ids = [str(test_data[i]) for i in range(len(test_data))]

# %% [markdown]
# **<h3>5. Encode labels from the training data and map to original strings</h3>**

# %%
# Encode the labels with integers
le = LabelEncoder()
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# Create a dictionary to map the encoded labels to their original strings
class_dict = dict(zip(le.transform(le.classes_), le.classes_))

# %% [markdown]
# **<h3>6. Load images into numpy arrays</h3>**

# %%
# Load the images and convert them to numpy arrays
def load_images(image_ids):
    images = []
    for image_id in image_ids:
        image_path = os.path.join(image_dir, str(image_id) + '.png')
        with Image.open(image_path) as img:
            img = img.convert('RGB')
            img = img.resize((img_cols, img_rows), resample=Resampling.BICUBIC)
            images.append(np.array(img))
    return np.array(images)

# %% [markdown]
# **<h3>7. Define the MLP model</h3>**

# %%
# Create the model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(img_rows, img_cols, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(512, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Out:
# 2023-03-03 15:59:29.946094: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# **<h3>8. Compile the model</h3>**
# * Before training a Kearas model, we need to compile it to set up all the options for training, such as loss function, optimizer, and evaluation metrics.
# * Here we will use cross entropy loss and the Adam optimizer. Our evaluation metric will be accuracy.

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=Adam(), metrics=['accuracy'])

# %% [markdown]
# **<h3>9. Load training images and split them into train and validation sets</h3>**

# %%
# Load the training images and split them into training and validation sets
X_train = load_images(train_ids)
X_train = X_train.astype('float32') / 255.0
y_train = np.eye(num_classes)[train_labels_encoded]
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# %% [markdown]
# **<h3>10. Train the model</h3>**

# %%
# Train the model
model.fit(X_train, y_train, batch_size=128, epochs=30, validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 22/22 [==============================] - 40s 2s/step - loss: 3.0000 - accuracy: 0.0486 - val_loss: 2.9921 - val_accuracy: 0.0642
# Epoch 2/30
# 22/22 [==============================] - 41s 2s/step - loss: 2.9426 - accuracy: 0.0789 - val_loss: 2.7707 - val_accuracy: 0.1858
# Epoch 3/30
# 22/22 [==============================] - 40s 2s/step - loss: 2.5250 - accuracy: 0.2057 - val_loss: 1.9226 - val_accuracy: 0.4500
# Epoch 4/30
# 22/22 [==============================] - 44s 2s/step - loss: 1.6440 - accuracy: 0.4504 - val_loss: 0.9746 - val_accuracy: 0.7042
# Epoch 5/30
# 22/22 [==============================] - 42s 2s/step - loss: 1.0484 - accuracy: 0.6361 - val_loss: 0.4930 - val_accuracy: 0.8550
# Epoch 6/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.5989 - accuracy: 0.7975 - val_loss: 0.2964 - val_accuracy: 0.9150
# Epoch 7/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.3955 - accuracy: 0.8693 - val_loss: 0.1537 - val_accuracy: 0.9575
# Epoch 8/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.2689 - accuracy: 0.9071 - val_loss: 0.0983 - val_accuracy: 0.9700
# Epoch 9/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.1635 - accuracy: 0.9454 - val_loss: 0.0685 - val_accuracy: 0.9742
# Epoch 10/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.1399 - accuracy: 0.9546 - val_loss: 0.0515 - val_accuracy: 0.9800
# Epoch 11/30
# 22/22 [==============================] - 44s 2s/step - loss: 0.1121 - accuracy: 0.9604 - val_loss: 0.0435 - val_accuracy: 0.9883
# Epoch 12/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.0914 - accuracy: 0.9696 - val_loss: 0.0378 - val_accuracy: 0.9867
# Epoch 13/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.0811 - accuracy: 0.9696 - val_loss: 0.0255 - val_accuracy: 0.9917
# Epoch 14/30
# 22/22 [==============================] - 46s 2s/step - loss: 0.0658 - accuracy: 0.9800 - val_loss: 0.0273 - val_accuracy: 0.9892
# Epoch 15/30
# 22/22 [==============================] - 45s 2s/step - loss: 0.0504 - accuracy: 0.9814 - val_loss: 0.0221 - val_accuracy: 0.9933
# Epoch 16/30
# 22/22 [==============================] - 44s 2s/step - loss: 0.0405 - accuracy: 0.9864 - val_loss: 0.0158 - val_accuracy: 0.9942
# Epoch 17/30
# 22/22 [==============================] - 41s 2s/step - loss: 0.0590 - accuracy: 0.9782 - val_loss: 0.0223 - val_accuracy: 0.9942
# Epoch 18/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.0604 - accuracy: 0.9771 - val_loss: 0.0239 - val_accuracy: 0.9917
# Epoch 19/30
# 22/22 [==============================] - 42s 2s/step - loss: 0.0415 - accuracy: 0.9864 - val_loss: 0.0218 - val_accuracy: 0.9925
# Epoch 20/30
# 22/22 [==============================] - 42s 2s/step - loss: 0.0481 - accuracy: 0.9836 - val_loss: 0.0128 - val_accuracy: 0.9958
# Epoch 21/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.0348 - accuracy: 0.9879 - val_loss: 0.0129 - val_accuracy: 0.9967
# Epoch 22/30
# 22/22 [==============================] - 43s 2s/step - loss: 0.0321 - accuracy: 0.9882 - val_loss: 0.0084 - val_accuracy: 0.9967
# Epoch 23/30
# 22/22 [==============================] - 45s 2s/step - loss: 0.0301 - accuracy: 0.9896 - val_loss: 0.0070 - val_accuracy: 0.9983
# Epoch 24/30
# 22/22 [==============================] - 48s 2s/step - loss: 0.0327 - accuracy: 0.9893 - val_loss: 0.0082 - val_accuracy: 0.9967
# Epoch 25/30
# 22/22 [==============================] - 42s 2s/step - loss: 0.0244 - accuracy: 0.9929 - val_loss: 0.0057 - val_accuracy: 0.9983
# Epoch 26/30
# 22/22 [==============================] - 44s 2s/step - loss: 0.0310 - accuracy: 0.9889 - val_loss: 0.0088 - val_accuracy: 0.9975
# Epoch 27/30
# 22/22 [==============================] - 47s 2s/step - loss: 0.0322 - accuracy: 0.9900 - val_loss: 0.0079 - val_accuracy: 0.9975
# Epoch 28/30
# 22/22 [==============================] - 47s 2s/step - loss: 0.0338 - accuracy: 0.9879 - val_loss: 0.0065 - val_accuracy: 0.9983
# Epoch 29/30
# 22/22 [==============================] - 44s 2s/step - loss: 0.0258 - accuracy: 0.9918 - val_loss: 0.0179 - val_accuracy: 0.9942
# Epoch 30/30
# 22/22 [==============================] - 44s 2s/step - loss: 0.0315 - accuracy: 0.9896 - val_loss: 0.0140 - val_accuracy: 0.9950

# %% [markdown]
# **<h3>11. Load test images</h3>**

# %%
# Load the test images
X_test = load_images(test_ids)
X_test = X_test.astype('float32') / 255.0

# %% [markdown]
# **<h3>12. Predict test images</h3>**

# %%
# Predict the labels for the test images
y_pred = model.predict(X_test)
y_pred_encoded = np.argmax(y_pred, axis=1)
# Out:
# 32/32 [==============================] - 5s 137ms/step

# %% [markdown]
# **<h3>13. Map labels and save the result on csv file</h3>**

# %%
# Map the predicted encoded labels to their original strings
y_pred_classes = [class_dict[y] for y in y_pred_encoded]

# Create a list of dictionaries for the test predictions
predictions = []
for i, image_id in enumerate(test_ids):
    predictions.append({'id': image_id, 'class': y_pred_classes[i]})

# Write the predictions to a CSV file
with open('working/submission.csv', 'w', newline='') as f:
    fieldnames = ['id', 'class']
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    for prediction in predictions:
        writer.writerow(prediction)

# %% [markdown]
# **<h3>*Optional: Print predicted labels for each test image</h3>**

# %%
# Output the predicted labels for each test image
for i, image_id in enumerate(test_ids):
    print(f"Image {image_id}: predicted class is {y_pred_classes[i]}")
# Out:
# Image 3991: predicted class is D3
# Image 1337: predicted class is A2
# Image 83: predicted class is C4
# Image 2688: predicted class is C2
# Image 4363: predicted class is D4
# Image 4106: predicted class is A3
# Image 1459: predicted class is A3
# Image 4467: predicted class is C2
# Image 4755: predicted class is A4
# Image 1446: predicted class is B4
# Image 3387: predicted class is B2
# Image 1478: predicted class is D2
# Image 3440: predicted class is A3
# Image 1111: predicted class is B1
# Image 3718: predicted class is C2
# Image 4230: predicted class is D3
# Image 783: predicted class is D4
# Image 3697: predicted class is D2
# Image 930: predicted class is D1
# Image 1287: predicted class is A1
# Image 2455: predicted class is D1
# Image 3359: predicted class is C0
# Image 3484: predicted class is A1
# Image 345: predicted class is A1
# Image 1556: predicted class is C4
# Image 2568: predicted class is B0
# Image 1405: predicted class is D4
# Image 3018: predicted class is B3
# Image 3511: predicted class is A0
# Image 2840: predicted class is D2
# Image 3346: predicted class is A3
# Image 4473: predicted class is D2
# Image 4710: predicted class is B4
# Image 1727: predicted class is C3
# Image 3228: predicted class is B4
# Image 4002: predicted class is A2
# Image 2645: predicted class is B0
# Image 3211: predicted class is B1
# Image 1077: predicted class is B2
# Image 2785: predicted class is A0
# Image 4704: predicted class is C1
# Image 1490: predicted class is D1
# Image 725: predicted class is A2
# Image 1510: predicted class is A1
# Image 2488: predicted class is D0
# Image 3493: predicted class is A4
# Image 2243: predicted class is D3
# Image 837: predicted class is D0
# Image 3123: predicted class is B4
# Image 2574: predicted class is A0
# Image 4520: predicted class is B2
# Image 1150: predicted class is B1
# Image 2374: predicted class is A3
# Image 3249: predicted class is A0
# Image 890: predicted class is A2
# Image 4690: predicted class is A4
# Image 1223: predicted class is A0
# Image 3307: predicted class is B3
# Image 3591: predicted class is A0
# Image 401: predicted class is C0
# Image 4973: predicted class is B1
# Image 2021: predicted class is C1
# Image 2496: predicted class is C3
# Image 4925: predicted class is C4
# Image 3815: predicted class is D4
# Image 562: predicted class is A3
# Image 3459: predicted class is C0
# Image 4211: predicted class is D2
# Image 1880: predicted class is A3
# Image 4937: predicted class is B0
# Image 3361: predicted class is B3
# Image 3104: predicted class is D2
# Image 2226: predicted class is A3
# Image 2018: predicted class is A3
# Image 4050: predicted class is A1
# Image 127: predicted class is B3
# Image 1336: predicted class is C3
# Image 3598: predicted class is C4
# Image 2030: predicted class is A2
# Image 1346: predicted class is A4
# Image 4607: predicted class is A0
# Image 3936: predicted class is C2
# Image 3020: predicted class is B4
# Image 4929: predicted class is D0
# Image 85: predicted class is D1
# Image 627: predicted class is A4
# Image 4311: predicted class is A4
# Image 1930: predicted class is D0
# Image 4212: predicted class is B1
# Image 1250: predicted class is A0
# Image 516: predicted class is C1
# Image 1865: predicted class is C1
# Image 1005: predicted class is A4
# Image 4018: predicted class is A2
# Image 1080: predicted class is C4
# Image 2283: predicted class is C3
# Image 4521: predicted class is C2
# Image 2005: predicted class is A2
# Image 732: predicted class is A1
# Image 2834: predicted class is A1
# Image 1081: predicted class is C3
# Image 4911: predicted class is D2
# Image 2058: predicted class is C2
# Image 1583: predicted class is C0
# Image 1745: predicted class is B3
# Image 1614: predicted class is C2
# Image 976: predicted class is A2
# Image 1584: predicted class is B3
# Image 151: predicted class is D3
# Image 3666: predicted class is C1
# Image 1499: predicted class is B1
# Image 3236: predicted class is C1
# Image 3799: predicted class is D1
# Image 3055: predicted class is B1
# Image 1369: predicted class is C4
# Image 3851: predicted class is A0
# Image 4366: predicted class is A0
# Image 552: predicted class is A3
# Image 4333: predicted class is C0
# Image 936: predicted class is C3
# Image 4671: predicted class is C1
# Image 4208: predicted class is B4
# Image 3377: predicted class is C2
# Image 4150: predicted class is C2
# Image 2175: predicted class is A4
# Image 4697: predicted class is A2
# Image 1669: predicted class is B4
# Image 2096: predicted class is B2
# Image 1859: predicted class is A0
# Image 2431: predicted class is A1
# Image 3501: predicted class is B4
# Image 4213: predicted class is A0
# Image 1137: predicted class is D0
# Image 3795: predicted class is B4
# Image 3380: predicted class is C3
# Image 1585: predicted class is B3
# Image 1804: predicted class is D3
# Image 40: predicted class is D0
# Image 2106: predicted class is D0
# Image 729: predicted class is A0
# Image 4202: predicted class is A2
# Image 3125: predicted class is A3
# Image 3561: predicted class is B1
# Image 1626: predicted class is A3
# Image 2534: predicted class is C4
# Image 4051: predicted class is A0
# Image 507: predicted class is D3
# Image 1756: predicted class is C3
# Image 3937: predicted class is C2
# Image 2176: predicted class is A1
# Image 4173: predicted class is D0
# Image 184: predicted class is D1
# Image 2290: predicted class is B3
# Image 4784: predicted class is B4
# Image 3389: predicted class is B1
# Image 4377: predicted class is B2
# Image 4758: predicted class is D1
# Image 4307: predicted class is B2
# Image 3849: predicted class is B4
# Image 4585: predicted class is B2
# Image 4039: predicted class is C1
# Image 2830: predicted class is D2
# Image 1611: predicted class is B4
# Image 1484: predicted class is A2
# Image 3967: predicted class is A0
# Image 3138: predicted class is B3
# Image 2028: predicted class is A4
# Image 217: predicted class is B0
# Image 1094: predicted class is A1
# Image 2296: predicted class is B1
# Image 2567: predicted class is C3
# Image 2930: predicted class is A4
# Image 3235: predicted class is C4
# Image 2265: predicted class is D1
# Image 1704: predicted class is D0
# Image 3243: predicted class is D4
# Image 558: predicted class is B0
# Image 878: predicted class is B4
# Image 3616: predicted class is C4
# Image 4176: predicted class is D0
# Image 268: predicted class is C3
# Image 1900: predicted class is D4
# Image 2315: predicted class is B1
# Image 298: predicted class is D3
# Image 4900: predicted class is C2
# Image 2216: predicted class is D1
# Image 3345: predicted class is D3
# Image 4062: predicted class is A4
# Image 4864: predicted class is B0
# Image 119: predicted class is D0
# Image 3840: predicted class is C2
# Image 2408: predicted class is D0
# Image 3393: predicted class is B4
# Image 3036: predicted class is D2
# Image 3618: predicted class is B4
# Image 4904: predicted class is C3
# Image 4427: predicted class is D4
# Image 1206: predicted class is D1
# Image 1249: predicted class is A4
# Image 2972: predicted class is C1
# Image 1949: predicted class is D1
# Image 3289: predicted class is A1
# Image 906: predicted class is A1
# Image 1377: predicted class is A0
# Image 4729: predicted class is B0
# Image 4069: predicted class is B2
# Image 4723: predicted class is C4
# Image 2186: predicted class is B1
# Image 2013: predicted class is A0
# Image 1098: predicted class is B0
# Image 3917: predicted class is D0
# Image 4638: predicted class is B3
# Image 3209: predicted class is C1
# Image 2038: predicted class is B1
# Image 1569: predicted class is C3
# Image 4256: predicted class is C1
# Image 4049: predicted class is C4
# Image 1933: predicted class is B4
# Image 737: predicted class is B3
# Image 4644: predicted class is D2
# Image 4656: predicted class is D0
# Image 3695: predicted class is C4
# Image 3955: predicted class is A1
# Image 503: predicted class is A4
# Image 3300: predicted class is B3
# Image 2108: predicted class is B4
# Image 1001: predicted class is D3
# Image 3130: predicted class is D4
# Image 4587: predicted class is A0
# Image 1916: predicted class is C0
# Image 2364: predicted class is B2
# Image 2402: predicted class is C4
# Image 2311: predicted class is A2
# Image 2445: predicted class is D4
# Image 2288: predicted class is B2
# Image 2966: predicted class is A4
# Image 2254: predicted class is D1
# Image 3335: predicted class is D1
# Image 2818: predicted class is C3
# Image 498: predicted class is B2
# Image 3750: predicted class is B0
# Image 3805: predicted class is A2
# Image 499: predicted class is B2
# Image 3780: predicted class is A0
# Image 4115: predicted class is C3
# Image 2399: predicted class is C0
# Image 242: predicted class is C0
# Image 2606: predicted class is D3
# Image 4870: predicted class is B0
# Image 538: predicted class is A0
# Image 3782: predicted class is D0
# Image 2658: predicted class is B2
# Image 4785: predicted class is B0
# Image 4687: predicted class is D0
# Image 2633: predicted class is B3
# Image 850: predicted class is D3
# Image 493: predicted class is D4
# Image 2236: predicted class is C1
# Image 405: predicted class is B2
# Image 187: predicted class is B2
# Image 1678: predicted class is D4
# Image 914: predicted class is C3
# Image 487: predicted class is A0
# Image 2901: predicted class is C1
# Image 2847: predicted class is C2
# Image 1821: predicted class is D3
# Image 1827: predicted class is A2
# Image 4222: predicted class is B0
# Image 2276: predicted class is C0
# Image 412: predicted class is B1
# Image 2469: predicted class is D2
# Image 821: predicted class is D0
# Image 1597: predicted class is B0
# Image 4777: predicted class is B1
# Image 4313: predicted class is C3
# Image 2695: predicted class is C0
# Image 3983: predicted class is A4
# Image 517: predicted class is A4
# Image 3547: predicted class is A3
# Image 4827: predicted class is C3
# Image 4280: predicted class is B3
# Image 1692: predicted class is B2
# Image 3806: predicted class is A2
# Image 3579: predicted class is D2
# Image 1667: predicted class is D0
# Image 4581: predicted class is D0
# Image 4651: predicted class is D0
# Image 3767: predicted class is C0
# Image 4546: predicted class is A2
# Image 3784: predicted class is C0
# Image 1119: predicted class is C1
# Image 2715: predicted class is C2
# Image 2947: predicted class is A2
# Image 2433: predicted class is D4
# Image 2222: predicted class is B3
# Image 3832: predicted class is B3
# Image 3854: predicted class is A2
# Image 3158: predicted class is A3
# Image 4428: predicted class is C1
# Image 4075: predicted class is C3
# Image 402: predicted class is D3
# Image 3221: predicted class is B1
# Image 3700: predicted class is B4
# Image 4987: predicted class is D3
# Image 2630: predicted class is C0
# Image 1713: predicted class is A3
# Image 3334: predicted class is C1
# Image 442: predicted class is B1
# Image 4616: predicted class is B0
# Image 504: predicted class is D4
# Image 3721: predicted class is B2
# Image 1872: predicted class is D2
# Image 474: predicted class is A1
# Image 1367: predicted class is A4
# Image 445: predicted class is C0
# Image 2085: predicted class is C3
# Image 424: predicted class is B2
# Image 1885: predicted class is B3
# Image 4429: predicted class is A3
# Image 238: predicted class is D3
# Image 4204: predicted class is A0
# Image 1209: predicted class is A1
# Image 1425: predicted class is B1
# Image 2067: predicted class is C4
# Image 3177: predicted class is A3
# Image 4159: predicted class is B0
# Image 1157: predicted class is D1
# Image 1749: predicted class is A1
# Image 51: predicted class is A0
# Image 4804: predicted class is A1
# Image 3717: predicted class is C1
# Image 1155: predicted class is A0
# Image 1225: predicted class is C4
# Image 4627: predicted class is D2
# Image 2579: predicted class is C2
# Image 1424: predicted class is C4
# Image 2019: predicted class is C0
# Image 3250: predicted class is D0
# Image 4407: predicted class is D1
# Image 3169: predicted class is B0
# Image 2932: predicted class is A3
# Image 553: predicted class is B4
# Image 262: predicted class is C1
# Image 1370: predicted class is D0
# Image 2952: predicted class is C3
# Image 4818: predicted class is A0
# Image 4439: predicted class is C4
# Image 4844: predicted class is C0
# Image 2522: predicted class is C4
# Image 4657: predicted class is C0
# Image 2346: predicted class is C2
# Image 3555: predicted class is B3
# Image 2566: predicted class is B2
# Image 1304: predicted class is A2
# Image 3313: predicted class is C4
# Image 756: predicted class is A3
# Image 4015: predicted class is C3
# Image 2048: predicted class is B3
# Image 2691: predicted class is C4
# Image 2105: predicted class is B0
# Image 2620: predicted class is A3
# Image 2978: predicted class is C4
# Image 1959: predicted class is A4
# Image 2873: predicted class is D3
# Image 4754: predicted class is A1
# Image 2859: predicted class is A1
# Image 3866: predicted class is D2
# Image 3378: predicted class is B0
# Image 3328: predicted class is D0
# Image 1650: predicted class is C2
# Image 1084: predicted class is C3
# Image 2791: predicted class is D1
# Image 1953: predicted class is A4
# Image 801: predicted class is D2
# Image 3896: predicted class is B1
# Image 1784: predicted class is D0
# Image 3477: predicted class is D4
# Image 2152: predicted class is C0
# Image 4389: predicted class is A3
# Image 3647: predicted class is C1
# Image 2382: predicted class is C1
# Image 3925: predicted class is C3
# Image 3061: predicted class is A3
# Image 3339: predicted class is C0
# Image 4136: predicted class is B4
# Image 122: predicted class is C2
# Image 1588: predicted class is B1
# Image 2141: predicted class is A4
# Image 34: predicted class is C4
# Image 1762: predicted class is C1
# Image 1398: predicted class is C0
# Image 1487: predicted class is C4
# Image 3904: predicted class is A4
# Image 4939: predicted class is C2
# Image 2799: predicted class is C4
# Image 414: predicted class is B2
# Image 4432: predicted class is C4
# Image 362: predicted class is D1
# Image 159: predicted class is B1
# Image 4219: predicted class is C1
# Image 1318: predicted class is D3
# Image 1079: predicted class is A1
# Image 4132: predicted class is A0
# Image 68: predicted class is D4
# Image 4130: predicted class is D4
# Image 211: predicted class is C4
# Image 59: predicted class is C0
# Image 2077: predicted class is A1
# Image 2618: predicted class is C0
# Image 4358: predicted class is C1
# Image 2406: predicted class is A2
# Image 3218: predicted class is A3
# Image 3234: predicted class is D0
# Image 1426: predicted class is A4
# Image 1038: predicted class is D1
# Image 984: predicted class is B3
# Image 4420: predicted class is B3
# Image 4577: predicted class is C4
# Image 3336: predicted class is C0
# Image 214: predicted class is B2
# Image 3496: predicted class is C2
# Image 3707: predicted class is C2
# Image 3698: predicted class is B3
# Image 3536: predicted class is C1
# Image 2858: predicted class is A0
# Image 660: predicted class is D3
# Image 3425: predicted class is C0
# Image 2180: predicted class is C1
# Image 1589: predicted class is A3
# Image 4379: predicted class is C1
# Image 1203: predicted class is C1
# Image 686: predicted class is B2
# Image 3044: predicted class is C4
# Image 1506: predicted class is A4
# Image 259: predicted class is D2
# Image 3098: predicted class is D3
# Image 2449: predicted class is C0
# Image 1483: predicted class is C4
# Image 118: predicted class is B4
# Image 3198: predicted class is C3
# Image 313: predicted class is D2
# Image 2949: predicted class is D2
# Image 4171: predicted class is C0
# Image 4249: predicted class is B3
# Image 1453: predicted class is D0
# Image 4801: predicted class is A1
# Image 601: predicted class is C3
# Image 998: predicted class is C0
# Image 4969: predicted class is A2
# Image 913: predicted class is D1
# Image 3830: predicted class is A2
# Image 599: predicted class is A2
# Image 4017: predicted class is C4
# Image 3895: predicted class is C2
# Image 736: predicted class is B3
# Image 1711: predicted class is B2
# Image 3027: predicted class is A3
# Image 506: predicted class is D0
# Image 3669: predicted class is D3
# Image 2323: predicted class is B2
# Image 3841: predicted class is D1
# Image 2396: predicted class is A0
# Image 2514: predicted class is A3
# Image 2006: predicted class is A2
# Image 1023: predicted class is A1
# Image 650: predicted class is A2
# Image 2703: predicted class is B2
# Image 1065: predicted class is C4
# Image 4459: predicted class is A1
# Image 2723: predicted class is D1
# Image 4053: predicted class is A2
# Image 4628: predicted class is A1
# Image 41: predicted class is A0
# Image 4325: predicted class is D2
# Image 2612: predicted class is D3
# Image 4958: predicted class is A3
# Image 1560: predicted class is C3
# Image 2921: predicted class is A4
# Image 2958: predicted class is C0
# Image 1171: predicted class is C1
# Image 4032: predicted class is D3
# Image 1507: predicted class is C4
# Image 220: predicted class is A3
# Image 784: predicted class is B3
# Image 3930: predicted class is A2
# Image 4043: predicted class is A4
# Image 2984: predicted class is C1
# Image 4000: predicted class is B4
# Image 2353: predicted class is B3
# Image 3778: predicted class is A3
# Image 803: predicted class is C0
# Image 982: predicted class is C3
# Image 2211: predicted class is C0
# Image 100: predicted class is D3
# Image 1549: predicted class is B1
# Image 1920: predicted class is B4
# Image 1532: predicted class is C1
# Image 1860: predicted class is B1
# Image 2357: predicted class is C0
# Image 703: predicted class is D4
# Image 3542: predicted class is A4
# Image 4279: predicted class is C4
# Image 4568: predicted class is D4
# Image 3025: predicted class is D3
# Image 932: predicted class is C3
# Image 3470: predicted class is B2
# Image 1956: predicted class is C1
# Image 3746: predicted class is A4
# Image 2261: predicted class is D2
# Image 771: predicted class is A4
# Image 3546: predicted class is C1
# Image 1408: predicted class is C4
# Image 2494: predicted class is C2
# Image 3946: predicted class is B3
# Image 2635: predicted class is C1
# Image 1354: predicted class is B3
# Image 2586: predicted class is A1
# Image 3410: predicted class is A3
# Image 897: predicted class is C3
# Image 1245: predicted class is B4
# Image 2872: predicted class is A1
# Image 3725: predicted class is C4
# Image 615: predicted class is C4
# Image 1194: predicted class is C1
# Image 1794: predicted class is A3
# Image 2640: predicted class is D0
# Image 2467: predicted class is A3
# Image 944: predicted class is B4
# Image 3453: predicted class is A0
# Image 1786: predicted class is B3
# Image 4233: predicted class is C3
# Image 2699: predicted class is C4
# Image 815: predicted class is B3
# Image 2797: predicted class is D2
# Image 4434: predicted class is D0
# Image 1963: predicted class is C2
# Image 2641: predicted class is A3
# Image 4146: predicted class is A2
# Image 1300: predicted class is D2
# Image 979: predicted class is A4
# Image 3193: predicted class is B4
# Image 4731: predicted class is D4
# Image 1581: predicted class is A3
# Image 1737: predicted class is B2
# Image 1910: predicted class is A1
# Image 1853: predicted class is C2
# Image 4241: predicted class is A0
# Image 3244: predicted class is B4
# Image 3433: predicted class is B4
# Image 4199: predicted class is B4
# Image 2917: predicted class is B3
# Image 2213: predicted class is C3
# Image 1906: predicted class is B4
# Image 760: predicted class is C4
# Image 3713: predicted class is B0
# Image 3207: predicted class is B1
# Image 2572: predicted class is C1
# Image 4298: predicted class is C0
# Image 3638: predicted class is B2
# Image 236: predicted class is A4
# Image 297: predicted class is D1
# Image 1621: predicted class is B4
# Image 790: predicted class is A4
# Image 3384: predicted class is A2
# Image 3710: predicted class is A3
# Image 4231: predicted class is D2
# Image 4289: predicted class is B2
# Image 1110: predicted class is A0
# Image 281: predicted class is B0
# Image 4716: predicted class is C3
# Image 747: predicted class is C0
# Image 2810: predicted class is B2
# Image 2520: predicted class is A0
# Image 1247: predicted class is C1
# Image 943: predicted class is D4
# Image 2596: predicted class is A2
# Image 389: predicted class is B1
# Image 165: predicted class is D0
# Image 218: predicted class is C1
# Image 3506: predicted class is C2
# Image 861: predicted class is D4
# Image 3609: predicted class is D0
# Image 3523: predicted class is A3
# Image 279: predicted class is C2
# Image 4661: predicted class is D2
# Image 4047: predicted class is B2
# Image 3645: predicted class is D2
# Image 3426: predicted class is C4
# Image 3213: predicted class is C3
# Image 4920: predicted class is C0
# Image 2205: predicted class is C0
# Image 3500: predicted class is A0
# Image 360: predicted class is A0
# Image 2657: predicted class is D1
# Image 2800: predicted class is D0
# Image 11: predicted class is A4
# Image 130: predicted class is A2
# Image 4730: predicted class is A4
# Image 3689: predicted class is C1
# Image 3614: predicted class is C2
# Image 4361: predicted class is A0
# Image 4897: predicted class is C1
# Image 4674: predicted class is B0
# Image 213: predicted class is C3
# Image 2230: predicted class is D0
# Image 969: predicted class is A1
# Image 2329: predicted class is B0
# Image 2451: predicted class is C2
# Image 4833: predicted class is A0
# Image 116: predicted class is D3
# Image 434: predicted class is A4
# Image 1382: predicted class is C3
# Image 2212: predicted class is B3
# Image 3155: predicted class is C0
# Image 1269: predicted class is C4
# Image 1764: predicted class is A4
# Image 2739: predicted class is A4
# Image 3628: predicted class is B3
# Image 4188: predicted class is D3
# Image 409: predicted class is D1
# Image 4343: predicted class is C2
# Image 1378: predicted class is A0
# Image 4195: predicted class is A2
# Image 2883: predicted class is D4
# Image 3072: predicted class is D4
# Image 4073: predicted class is B1
# Image 742: predicted class is B2
# Image 1003: predicted class is A2
# Image 4480: predicted class is C0
# Image 1438: predicted class is D1
# Image 2811: predicted class is B1
# Image 1986: predicted class is B1
# Image 1642: predicted class is C3
# Image 1476: predicted class is D1
# Image 860: predicted class is C1
# Image 632: predicted class is B0
# Image 4118: predicted class is A0
# Image 1576: predicted class is A4
# Image 1434: predicted class is C4
# Image 1668: predicted class is D3
# Image 144: predicted class is D2
# Image 3050: predicted class is D4
# Image 791: predicted class is A1
# Image 3532: predicted class is D0
# Image 978: predicted class is B2
# Image 4166: predicted class is B0
# Image 3770: predicted class is C2
# Image 1864: predicted class is A1
# Image 4221: predicted class is A4
# Image 3395: predicted class is D0
# Image 4898: predicted class is D3
# Image 1347: predicted class is B3
# Image 4610: predicted class is C3
# Image 2376: predicted class is B2
# Image 1414: predicted class is D1
# Image 864: predicted class is C3
# Image 1941: predicted class is D1
# Image 3916: predicted class is C1
# Image 3096: predicted class is D2
# Image 2867: predicted class is A0
# Image 1391: predicted class is A3
# Image 443: predicted class is C1
# Image 1138: predicted class is C4
# Image 2145: predicted class is D1
# Image 3787: predicted class is B0
# Image 778: predicted class is B0
# Image 1573: predicted class is B1
# Image 2427: predicted class is D1
# Image 99: predicted class is A1
# Image 2683: predicted class is B1
# Image 4533: predicted class is A3
# Image 4038: predicted class is B0
# Image 465: predicted class is C4
# Image 3798: predicted class is A1
# Image 2573: predicted class is A0
# Image 3442: predicted class is D2
# Image 1192: predicted class is D4
# Image 4471: predicted class is A3
# Image 770: predicted class is C4
# Image 3768: predicted class is B4
# Image 322: predicted class is D1
# Image 4155: predicted class is C3
# Image 3342: predicted class is C3
# Image 4727: predicted class is B1
# Image 3356: predicted class is A1
# Image 581: predicted class is D3
# Image 4641: predicted class is A2
# Image 3947: predicted class is C4
# Image 3100: predicted class is D4
# Image 2242: predicted class is D4
# Image 1689: predicted class is D0
# Image 1036: predicted class is B0
# Image 3814: predicted class is C0
# Image 4522: predicted class is B0
# Image 1248: predicted class is A1
# Image 877: predicted class is A3
# Image 2702: predicted class is A4
# Image 2274: predicted class is B3
# Image 1550: predicted class is D1
# Image 147: predicted class is C0
# Image 1803: predicted class is B2
# Image 186: predicted class is B1
# Image 1143: predicted class is A2
# Image 1064: predicted class is D3
# Image 4286: predicted class is A4
# Image 241: predicted class is B3
# Image 4584: predicted class is C4
# Image 3069: predicted class is D1
# Image 2183: predicted class is D2
# Image 4308: predicted class is D0
# Image 2727: predicted class is B0
# Image 2241: predicted class is C4
# Image 1714: predicted class is C0
# Image 36: predicted class is B2
# Image 844: predicted class is A2
# Image 775: predicted class is B1
# Image 4860: predicted class is B2
# Image 3563: predicted class is B0
# Image 4097: predicted class is D4
# Image 4397: predicted class is B0
# Image 1787: predicted class is C4
# Image 1659: predicted class is B1
# Image 2905: predicted class is B2
# Image 2434: predicted class is B3
# Image 4912: predicted class is A0
# Image 3180: predicted class is C1
# Image 759: predicted class is B3
# Image 1979: predicted class is A3
# Image 4498: predicted class is B1
# Image 1383: predicted class is D2
# Image 2997: predicted class is C3
# Image 1258: predicted class is B0
# Image 3971: predicted class is C0
# Image 3032: predicted class is A0
# Image 42: predicted class is D4
# Image 2050: predicted class is D0
# Image 3201: predicted class is D4
# Image 15: predicted class is C1
# Image 4177: predicted class is A4
# Image 2967: predicted class is C4
# Image 518: predicted class is D3
# Image 2478: predicted class is B3
# Image 1162: predicted class is C3
# Image 2253: predicted class is A2
# Image 2796: predicted class is B2
# Image 3682: predicted class is A4
# Image 3792: predicted class is A4
# Image 216: predicted class is C2
# Image 4689: predicted class is C4
# Image 4421: predicted class is B0
# Image 3371: predicted class is D4
# Image 4299: predicted class is A2
# Image 1781: predicted class is A1
# Image 1895: predicted class is B2
# Image 8: predicted class is D1
# Image 4812: predicted class is A2
# Image 3248: predicted class is D3
# Image 2153: predicted class is A4
# Image 691: predicted class is A2
# Image 1352: predicted class is A3
# Image 1978: predicted class is B1
# Image 519: predicted class is B4
# Image 3877: predicted class is D0
# Image 256: predicted class is C0
# Image 544: predicted class is B4
# Image 383: predicted class is B2
# Image 4853: predicted class is A3
# Image 2460: predicted class is C1
# Image 3981: predicted class is D0
# Image 4396: predicted class is A1
# Image 2020: predicted class is A1
# Image 4619: predicted class is B0
# Image 4341: predicted class is C3
# Image 4237: predicted class is C3
# Image 3817: predicted class is D3
# Image 2740: predicted class is D4
# Image 515: predicted class is A2
# Image 4706: predicted class is A3
# Image 4236: predicted class is A3
# Image 4163: predicted class is B1
# Image 2091: predicted class is C1
# Image 1639: predicted class is A0
# Image 1448: predicted class is A2
# Image 3560: predicted class is C2
# Image 4980: predicted class is A4
# Image 4779: predicted class is B2
# Image 1267: predicted class is C4
# Image 4647: predicted class is B1
# Image 3257: predicted class is A1
# Image 2548: predicted class is C4
# Image 398: predicted class is B2
# Image 2457: predicted class is A0
# Image 4274: predicted class is D1
# Image 3462: predicted class is D3
# Image 288: predicted class is B0
# Image 1574: predicted class is D0
# Image 386: predicted class is A0
# Image 1451: predicted class is D2
# Image 4783: predicted class is A1
# Image 2998: predicted class is C4
# Image 4082: predicted class is D2
# Image 2911: predicted class is A0
# Image 1196: predicted class is C3
# Image 50: predicted class is C2
# Image 3935: predicted class is A3
# Image 1763: predicted class is C0
# Image 176: predicted class is D1
# Image 86: predicted class is D0
# Image 2681: predicted class is C4
# Image 2149: predicted class is A0
# Image 2622: predicted class is C3
# Image 2310: predicted class is C1
# Image 1861: predicted class is B2
# Image 2583: predicted class is B3
# Image 3439: predicted class is C0
# Image 96: predicted class is C2
# Image 2747: predicted class is D3
# Image 4862: predicted class is C4
# Image 2939: predicted class is A4
# Image 1855: predicted class is A4
# Image 1862: predicted class is D4
# Image 2182: predicted class is A4
# Image 4609: predicted class is A4
# Image 3172: predicted class is C4
# Image 1106: predicted class is C0
# Image 2124: predicted class is A0
# Image 7: predicted class is B0
# Image 3715: predicted class is B3
# Image 1389: predicted class is D4
# Image 4887: predicted class is B0
# Image 2041: predicted class is D3
# Image 2788: predicted class is A2
# Image 3973: predicted class is B4
# Image 3165: predicted class is B0
# Image 3364: predicted class is D3
# Image 3634: predicted class is B3
# Image 3918: predicted class is D1
# Image 1092: predicted class is B1
# Image 246: predicted class is A4
# Image 2397: predicted class is C0
# Image 2263: predicted class is D0
# Image 1709: predicted class is D4
# Image 3516: predicted class is B0
# Image 3660: predicted class is B1
# Image 4224: predicted class is B1
# Image 4501: predicted class is A0
# Image 4676: predicted class is A3
# Image 608: predicted class is D0
# Image 3702: predicted class is A3
# Image 3166: predicted class is D0
# Image 1379: predicted class is C1
# Image 2380: predicted class is A4
# Image 3275: predicted class is B3
# Image 2040: predicted class is C0
# Image 274: predicted class is D2
# Image 4457: predicted class is B3
# Image 1658: predicted class is D0
# Image 415: predicted class is D1
# Image 2016: predicted class is D2
# Image 4248: predicted class is C3
# Image 963: predicted class is A4
# Image 3543: predicted class is B0
# Image 3816: predicted class is C4
# Image 2821: predicted class is B4
# Image 230: predicted class is A2
# Image 2763: predicted class is D1
# Image 2037: predicted class is D0
# Image 1570: predicted class is C1
# Image 4554: predicted class is A1
# Image 1675: predicted class is B0
# Image 1645: predicted class is C3
# Image 2536: predicted class is A0
# Image 2503: predicted class is B2
# Image 221: predicted class is D1
# Image 4976: predicted class is D4
# Image 2372: predicted class is A4
# Image 303: predicted class is D1
# Image 4938: predicted class is D1
# Image 3869: predicted class is D4
# Image 2898: predicted class is C3
# Image 779: predicted class is A0
# Image 4182: predicted class is C3
# Image 3319: predicted class is D3
# Image 4536: predicted class is C2
# Image 3804: predicted class is A2
# Image 4637: predicted class is C3
# Image 3924: predicted class is A2
# Image 222: predicted class is A1
# Image 3183: predicted class is A3
# Image 768: predicted class is B0
# Image 1263: predicted class is B1
# Image 4009: predicted class is D0
# Image 4515: predicted class is A3
# Image 1350: predicted class is C0
# Image 3184: predicted class is C1
# Image 3962: predicted class is C2
# Image 2575: predicted class is D4
# Image 1178: predicted class is A2
# Image 1057: predicted class is B3
# Image 678: predicted class is C2
# Image 3488: predicted class is D4
# Image 3238: predicted class is B4
# Image 1521: predicted class is B3
# Image 4825: predicted class is B3
# Image 453: predicted class is B0
# Image 2900: predicted class is D2
# Image 4394: predicted class is A4
# Image 4650: predicted class is D0
# Image 3613: predicted class is C4
# Image 3038: predicted class is B0
# Image 2172: predicted class is B4
# Image 169: predicted class is C3
# Image 4793: predicted class is C3
# Image 2524: predicted class is A1
# Image 3413: predicted class is B1
# Image 4630: predicted class is A4
# Image 4909: predicted class is D4
# Image 3966: predicted class is C4
# Image 927: predicted class is A0
# Image 374: predicted class is C0
# Image 3375: predicted class is D0
# Image 3299: predicted class is B1
# Image 1183: predicted class is D4
# Image 4633: predicted class is D4
# Image 3771: predicted class is B0
# Image 2229: predicted class is C3
# Image 1997: predicted class is A0
# Image 2664: predicted class is C3
# Image 3024: predicted class is B3
# Image 3863: predicted class is D4
# Image 4422: predicted class is D1
# Image 3347: predicted class is B3
# Image 4921: predicted class is A3
# Image 4664: predicted class is A0
# Image 4691: predicted class is D1
# Image 1912: predicted class is C0
# Image 3524: predicted class is A1
# Image 2933: predicted class is C0
# Image 3964: predicted class is B0
# Image 2247: predicted class is D4
# Image 4388: predicted class is B2
# Image 4167: predicted class is D3
# Image 4468: predicted class is A2
# Image 3872: predicted class is A4
# Image 754: predicted class is A4
# Image 1607: predicted class is A1
# Image 3090: predicted class is D4
# Image 431: predicted class is B2
# Image 4463: predicted class is D3
# Image 646: predicted class is C4
# Image 1710: predicted class is C4
# Image 336: predicted class is B1
# Image 1074: predicted class is B2
# Image 4435: predicted class is D4
# Image 755: predicted class is A2
# Image 3554: predicted class is C1
# Image 2003: predicted class is A0
# Image 4190: predicted class is C4
# Image 1027: predicted class is B2
# Image 3388: predicted class is D4
# Image 822: predicted class is C3
# Image 1595: predicted class is C0
# Image 734: predicted class is B2
# Image 854: predicted class is D2
# Image 1357: predicted class is D2
# Image 3131: predicted class is C4
# Image 4328: predicted class is C1
# Image 1082: predicted class is B4
# Image 3015: predicted class is B2
# Image 1474: predicted class is B0
# Image 2206: predicted class is C1
# Image 2139: predicted class is D4
# Image 1410: predicted class is A4
# Image 4088: predicted class is A2
# Image 1940: predicted class is B1
# Image 2977: predicted class is A0
# Image 2724: predicted class is D2
# Image 2680: predicted class is D3
# Image 4513: predicted class is D1
# Image 3333: predicted class is D4
# Image 2188: predicted class is B1
# Image 2333: predicted class is B1
# Image 2929: predicted class is C0
# Image 940: predicted class is D1
# Image 1052: predicted class is A1
# Image 88: predicted class is B0
# Image 3295: predicted class is C1
# Image 106: predicted class is C0
# Image 1884: predicted class is D4
# Image 1528: predicted class is B1
# Image 4001: predicted class is A4
# Image 668: predicted class is B3
# Image 4985: predicted class is C2
# Image 4978: predicted class is B4
# Image 4561: predicted class is A4
# Image 947: predicted class is D4
# Image 294: predicted class is D0
# Image 2068: predicted class is A1
# Image 607: predicted class is C0
# Image 4271: predicted class is C3
